# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Data extraction

# %%
import pandas as pd

def read_data(file_path, sheet_name):
    """
    read excel data

    parameter:
    file_path: Excel file path。
    sheet_name: worksheet name。

    return:
    df: read DataFrame。
    """
    return pd.read_excel(file_path, sheet_name=sheet_name)

def split_and_adjust_data(df):
    """
    Sperate dataframe as two tables, and change columns name

    parameter:
    df: original DataFrame。

    Return:
    df1, df2: sperate and adjust as DataFrame。
    """
    # find out all missing value
    full_missing_rows = df[df.isna().all(axis=1)]

    if full_missing_rows.empty:
        # If there are no rows with missing values, return the original data and an empty DataFrame
        return df, pd.DataFrame()

    # The next row index of the last row with all missing values
    last_missing_index = full_missing_rows.index[-1]

    # Separate into two tables: df1 is the part before the missing values, df2 is the part after the missing values
    df1 = df.iloc[:last_missing_index]
    df2 = df.iloc[last_missing_index + 1:]

    # df1 uses the third row as the table header
    df1.columns = df1.iloc[2]
    df1 = df1[3:].reset_index(drop=True)  # Data starting from the fouth row and resetting the index


    # The third row of df2 is used as the header
    df2.columns = df2.iloc[2]  # The third line is used as header
    df2 = df2[3:].reset_index(drop=True)  # Data starting from the fourth row and resetting the index

    # Make sure the first column of the table header of df1 and df2 is 'Base Run' and the second column is 'Date'
    df1.columns = ['Base Run' if i == 0 else df1.columns[i] for i in range(len(df1.columns))]
    df1.columns = ['Base Run', 'Date'] + df1.columns[2:].tolist()

    df2.columns = ['Base Run' if i == 0 else df2.columns[i] for i in range(len(df2.columns))]
    df2.columns = ['Base Run', 'Date'] + df2.columns[2:].tolist()

    # Remove blank values ​​from the column names of df2 and move the column name of the fourth column forward to the third column
    new_columns = [col if pd.notna(col) else None for col in df2.columns]
    new_columns = [col for col in new_columns if col is not None]

    # If the third column is blank, replace it with the name of the fourth column and add an Unknown column name
    if new_columns[2] is None:
        new_columns[2] = new_columns[3]
        new_columns[3] = 'Unknown'  # replace with Unknown
    else:
        new_columns.append('Unknown')  # If the third column is not blank, add an Unknown column name at the end

    # Make sure the number of column names matches the number of columns of df2
    if len(new_columns) < len(df2.columns):
        new_columns.append('Unknown')

    df2.columns = new_columns

    return df1, df2

# File path and worksheet name
file_path = '/content/drive/MyDrive/713 Capstone Project (DA)/RUN3PM10QUS_base.xlsx'
sheet_name = 'Contributions'

# Reading Excel Files
df = read_data(file_path, sheet_name)

# Separate data into two tables and adjust column names
df1, df2 = split_and_adjust_data(df)



# Drop the rightmost column of df1 and df2
df1 = df1.drop(df1.columns[-1], axis=1)
df2 = df2.drop(df2.columns[-1], axis=1)  # 移除补充的Unknown列

# print results
print("First Table (df1):")
print(df1)
print("\nSecond Table (df2):")
print(df2)
# Out:
# First Table (df1):
#      Base Run       Date Soil/Road dust Sea salt Diesel vehicles  \
# 0           1 2006-01-06        0.52359    1.237          1.6154
# 1           1 2006-01-07        0.54113    0.894          1.0639
# 2           1 2006-01-08        0.81198   1.4498          1.1626
# 3           1 2006-01-09         1.0009    1.917         0.81576
# 4           1 2006-01-11        0.69889   1.7211         0.75511
# ...       ...        ...            ...      ...             ...
# 3671        1 2022-12-03        0.37984   1.1617         0.25032
# 3672        1 2022-12-09       -0.16833  0.55372         0.20551
# 3673        1 2022-12-15        0.20323  0.15687         0.12945
# 3674        1 2022-12-21        0.54835   0.3482         0.22288
# 3675        1 2022-12-27        0.40598  0.64801        -0.10268
#
#      Biomass burning Construction Petrol vehicles Sulphate/Marine diesel
# 0            0.65492       0.0653         0.91454                0.59039
# 1            0.22508      0.10771         0.91505                0.45061
# 2            0.33601      0.20339         0.71507                0.59531
# 3            0.25201      0.29707          2.1873                 1.6421
# 4             0.2161      0.60108         0.68028                 1.2134
# ...              ...          ...             ...                    ...
# 3671         0.44057      0.45468         0.34866                0.36294
# 3672         0.10837      0.20553         0.33374                 0.5296
# 3673         0.13114      0.13171          0.3641                0.20081
# 3674          0.3257      0.60809         0.45162                0.88107
# 3675         0.32348      0.22307         0.70669                 1.5581
#
# [3676 rows x 9 columns]
#
# Second Table (df2):
#      Base Run       Date  Factor 1   Factor 2  Factor 3  Factor 4  Factor 5  \
# 0           1 2006-01-06  0.513317   8.439309   6.31056  1.247557  0.021853
# 1           1 2006-01-07  0.530513   6.099226  4.156125  0.428755  0.036045
# 2           1 2006-01-08  0.796049   9.891116  4.541697  0.640065  0.068064
# 3           1 2006-01-09  0.981262  13.078541  3.186766  0.480054  0.099414
# 4           1 2006-01-11  0.685178  11.742033  2.949837  0.411649  0.201151
# ...       ...        ...       ...        ...       ...       ...       ...
# 3671        1 2022-12-03  0.372388   7.925582  0.977875  0.839242  0.152159
# 3672        1 2022-12-09 -0.165027   3.777699  0.802825  0.206434  0.068781
# 3673        1 2022-12-15  0.199243    1.07023  0.505696  0.249809  0.044077
# 3674        1 2022-12-21  0.537591    2.37556  0.870681  0.620426  0.203497
# 3675        1 2022-12-27  0.398015   4.420983 -0.401119  0.616197   0.07465
#
#       Factor 6  Factor 7
# 0     0.470458  0.986719
# 1      0.47072  0.753104
# 2     0.367846  0.994942
# 3     1.125191  2.744442
# 4      0.34995  2.027955
# ...        ...       ...
# 3671  0.179358  0.606582
# 3672  0.171683   0.88512
# 3673    0.1873  0.335614
# 3674  0.232322  1.472532
# 3675  0.363535  2.604053
#
# [3676 rows x 9 columns]

# %% [markdown]
# # Create Database

# %%
import sqlite3
import os

def drop_database(db_filename):
    # If the database file exists, delete it
    if os.path.exists(db_filename):
        os.remove(db_filename)
        print(f"Database file {db_filename} has been deleted.")
    else:
        print(f"Database file {db_filename} does not exist.")

def create_database(db_filename):
    # Connect to a SQLite database, this will create a new empty database file
    conn = sqlite3.connect(db_filename)

    # SQL statement to create a table
    create_dates_table = """
    CREATE TABLE IF NOT EXISTS Dates (
        date_id INTEGER PRIMARY KEY AUTOINCREMENT,
        date TEXT NOT NULL
    );
    """
    create_factors_table = """
    CREATE TABLE IF NOT EXISTS Factors (
        factor_id INTEGER PRIMARY KEY AUTOINCREMENT,
        factor_name TEXT NOT NULL
    );
    """
    create_contributions_table = """
    CREATE TABLE IF NOT EXISTS Contributions (
        contribution_id INTEGER PRIMARY KEY AUTOINCREMENT,
        date_id INTEGER,
        factor_id INTEGER,
        contribution_value REAL,
        FOREIGN KEY (date_id) REFERENCES Dates(date_id),
        FOREIGN KEY (factor_id) REFERENCES Factors(factor_id)
    );
    """

    # Execute SQL statements to create tables
    cursor = conn.cursor()
    cursor.execute(create_dates_table)
    cursor.execute(create_factors_table)
    cursor.execute(create_contributions_table)

    # confirm operation
    conn.commit()

    # close connections
    conn.close()
    print(f"Database file {db_filename} has been created.")

# using function
db_filename = 'trend_analysis_contributions.db'
drop_database(db_filename)  # Delete database
create_database(db_filename)  # Create database
# Out:
# Database file trend_analysis_contributions.db has been deleted.
# Database file trend_analysis_contributions.db has been created.

# %% [markdown]
# # Insert Data

# %%
import sqlite3
import pandas as pd

def insert_dates_to_table(db_filename, df1):
    # Connecting to a SQLite Database
    conn = sqlite3.connect(db_filename)
    cursor = conn.cursor()

    # Prepare SQL statements to insert data
    insert_date = """
    INSERT INTO Dates (date) VALUES (?)
    """

    # Make sure that the data in the Date column is of string type and handle null values
    df1['Date'] = df1['Date'].astype(str)
    df1 = df1.dropna(subset=['Date'])  # delete null value

    # Traverse the Date column of df1 and insert it into the database
    for index, row in df1.iterrows():
        # Perform an insert operation
        cursor.execute(insert_date, (row['Date'],))

    # confirm opearation
    conn.commit()
    print("Dates have been inserted into the Dates table.")

    # close connection
    conn.close()

# define database
db_filename = 'trend_analysis_contributions.db'

# using function
insert_dates_to_table(db_filename, df1)
# Out:
# Dates have been inserted into the Dates table.

# %%
import sqlite3
import pandas as pd

def insert_factors_to_table(db_filename, df1):
    # Connecting to a SQLite Database
    conn = sqlite3.connect(db_filename)
    cursor = conn.cursor()

    # Prepare SQL statements to insert data
    insert_factor = """
    INSERT INTO Factors (factor_name) VALUES (?)
    """

    # Traverse the column names of df1 starting from the third column and insert them into the database
    for column_name in df1.columns[2:]:  # Starting from the third column, index is 2
        # Perform an insert operation
        cursor.execute(insert_factor, (column_name,))

    # confirm operation
    conn.commit()
    print("Factors have been inserted into the Factors table.")

    # close connection
    conn.close()

# define database
db_filename = 'trend_analysis_contributions.db'

# using function
insert_factors_to_table(db_filename, df1)
# Out:
# Factors have been inserted into the Factors table.

# %%
import sqlite3
import pandas as pd

def insert_contributions_to_table(db_filename, df1):
    try:
        # Connecting to a SQLite Database
        conn = sqlite3.connect(db_filename)
        cursor = conn.cursor()
        print("Connected to the database.")

        # Prepare SQL statement to query date_id
        get_date_id = "SELECT date_id FROM Dates WHERE date = ?"

        # Prepare the SQL statement to query factor_id
        get_factor_id = "SELECT factor_id FROM Factors WHERE factor_name = ?"

        # Prepare SQL statements to insert into the Contributions table
        insert_contribution = """
        INSERT INTO Contributions (date_id, factor_id, contribution_value) VALUES (?, ?, ?)
        """

        # Traverse each row of df1
        for index, row in df1.iterrows():
            # Get date_id
            cursor.execute(get_date_id, (str(row['Date']),))
            date_id_result = cursor.fetchone()
            if date_id_result:
                date_id = date_id_result[0]
                print(f"Found date_id {date_id} for date {row['Date']}")
            else:
                print(f"No matching date_id found for date {row['Date']}")
                continue

            # Iterate through the column names and values ​​of df1 starting from the third column
            for column_name in df1.columns[2:]:
                # 获取factor_id
                cursor.execute(get_factor_id, (str(column_name),))
                factor_id_result = cursor.fetchone()
                if factor_id_result:
                    factor_id = factor_id_result[0]
                    print(f"Found factor_id {factor_id} for factor {column_name}")
                    # insert contribution value
                    cursor.execute(insert_contribution, (date_id, factor_id, row[column_name]))
                    print(f"Inserted contribution value {row[column_name]} for date_id {date_id} and factor_id {factor_id}")
                else:
                    print(f"No matching factor_id found for factor {column_name}")

        # confirm opeartion
        conn.commit()
        print("Contributions have been inserted into the Contributions table.")

        # close connection
        conn.close()
        print("Database connection closed.")
    except Exception as e:
        print(f"An error occurred: {e}")

# define database
db_filename = 'trend_analysis_contributions.db'

# using function
insert_contributions_to_table(db_filename, df1)
# Out:
# Streaming output truncated to the last 5000 lines.
# Inserted contribution value 0.56058 for date_id 3343 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.24704 for date_id 3343 and factor_id 7
# Found date_id 3344 for date 2016-12-25
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.29058 for date_id 3344 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 1.2739 for date_id 3344 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.31228 for date_id 3344 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.91906 for date_id 3344 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.065909 for date_id 3344 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.61647 for date_id 3344 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.35485 for date_id 3344 and factor_id 7
# Found date_id 3345 for date 2016-12-26
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.36047 for date_id 3345 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.623 for date_id 3345 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.34664 for date_id 3345 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.2569 for date_id 3345 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.034866 for date_id 3345 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.49424 for date_id 3345 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.70662 for date_id 3345 and factor_id 7
# Found date_id 3346 for date 2016-12-27
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.69972 for date_id 3346 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.76313 for date_id 3346 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.56302 for date_id 3346 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.95672 for date_id 3346 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.26173 for date_id 3346 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.70551 for date_id 3346 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.60784 for date_id 3346 and factor_id 7
# Found date_id 3347 for date 2016-12-28
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.75334 for date_id 3347 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.99788 for date_id 3347 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.64406 for date_id 3347 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.312 for date_id 3347 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.57105 for date_id 3347 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.20291 for date_id 3347 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.30109 for date_id 3347 and factor_id 7
# Found date_id 3348 for date 2017-01-11
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 1.225 for date_id 3348 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.29258 for date_id 3348 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.94201 for date_id 3348 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.1258 for date_id 3348 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 1.0914 for date_id 3348 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.67426 for date_id 3348 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.113 for date_id 3348 and factor_id 7
# Found date_id 3349 for date 2017-01-23
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.92619 for date_id 3349 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 1.8631 for date_id 3349 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.64804 for date_id 3349 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.4291 for date_id 3349 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.6553 for date_id 3349 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.025278 for date_id 3349 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.16239 for date_id 3349 and factor_id 7
# Found date_id 3350 for date 2017-01-29
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 1.2914 for date_id 3350 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 1.5124 for date_id 3350 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.7916 for date_id 3350 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.5346 for date_id 3350 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.57584 for date_id 3350 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.44638 for date_id 3350 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.29318 for date_id 3350 and factor_id 7
# Found date_id 3351 for date 2017-02-04
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.52299 for date_id 3351 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.9719 for date_id 3351 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.28627 for date_id 3351 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.1897 for date_id 3351 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value -0.052256 for date_id 3351 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.13165 for date_id 3351 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.60828 for date_id 3351 and factor_id 7
# Found date_id 3352 for date 2017-02-10
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 1.5054 for date_id 3352 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.44842 for date_id 3352 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.62615 for date_id 3352 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.7548 for date_id 3352 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.68718 for date_id 3352 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.25177 for date_id 3352 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.98503 for date_id 3352 and factor_id 7
# Found date_id 3353 for date 2017-02-16
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.086403 for date_id 3353 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.3524 for date_id 3353 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.13575 for date_id 3353 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.0016 for date_id 3353 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.30767 for date_id 3353 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.081266 for date_id 3353 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 2.8928 for date_id 3353 and factor_id 7
# Found date_id 3354 for date 2017-02-22
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 1.0115 for date_id 3354 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.86726 for date_id 3354 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.45136 for date_id 3354 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.3717 for date_id 3354 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.66549 for date_id 3354 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 1.352 for date_id 3354 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.3302 for date_id 3354 and factor_id 7
# Found date_id 3355 for date 2017-02-28
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.76248 for date_id 3355 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.10729 for date_id 3355 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.45209 for date_id 3355 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.89709 for date_id 3355 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 1.058 for date_id 3355 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.22256 for date_id 3355 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.4623 for date_id 3355 and factor_id 7
# Found date_id 3356 for date 2017-03-06
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.5238 for date_id 3356 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.22826 for date_id 3356 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.51595 for date_id 3356 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.60152 for date_id 3356 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.79744 for date_id 3356 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.57631 for date_id 3356 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.81083 for date_id 3356 and factor_id 7
# Found date_id 3357 for date 2017-03-30
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.42084 for date_id 3357 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.047701 for date_id 3357 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.8006 for date_id 3357 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.0325 for date_id 3357 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.48738 for date_id 3357 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 1.1453 for date_id 3357 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.50368 for date_id 3357 and factor_id 7
# Found date_id 3358 for date 2017-04-05
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.39577 for date_id 3358 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.94253 for date_id 3358 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.78249 for date_id 3358 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.3916 for date_id 3358 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.49059 for date_id 3358 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.10403 for date_id 3358 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.23642 for date_id 3358 and factor_id 7
# Found date_id 3359 for date 2017-04-11
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.25358 for date_id 3359 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.86006 for date_id 3359 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.31414 for date_id 3359 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.0783 for date_id 3359 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.99571 for date_id 3359 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.16956 for date_id 3359 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.1401 for date_id 3359 and factor_id 7
# Found date_id 3360 for date 2017-04-23
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.5103 for date_id 3360 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.06718 for date_id 3360 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value -0.011596 for date_id 3360 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.73607 for date_id 3360 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.26089 for date_id 3360 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.76217 for date_id 3360 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.4388 for date_id 3360 and factor_id 7
# Found date_id 3361 for date 2017-04-29
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.32992 for date_id 3361 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.40062 for date_id 3361 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.38276 for date_id 3361 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.65882 for date_id 3361 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.49004 for date_id 3361 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.08919 for date_id 3361 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 2.0711 for date_id 3361 and factor_id 7
# Found date_id 3362 for date 2017-05-05
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.50935 for date_id 3362 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 1.4172 for date_id 3362 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 1.0284 for date_id 3362 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.3409 for date_id 3362 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.45445 for date_id 3362 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 1.4219 for date_id 3362 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.0031667 for date_id 3362 and factor_id 7
# Found date_id 3363 for date 2017-05-11
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.11175 for date_id 3363 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 1.4901 for date_id 3363 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.2306 for date_id 3363 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.76692 for date_id 3363 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.24657 for date_id 3363 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.2 for date_id 3363 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.3514 for date_id 3363 and factor_id 7
# Found date_id 3364 for date 2017-05-17
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.49959 for date_id 3364 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.94529 for date_id 3364 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.46414 for date_id 3364 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.0175 for date_id 3364 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 1.031 for date_id 3364 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.082087 for date_id 3364 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.0917 for date_id 3364 and factor_id 7
# Found date_id 3365 for date 2017-05-23
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 3.094 for date_id 3365 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.0092545 for date_id 3365 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 1.7704 for date_id 3365 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 2.4724 for date_id 3365 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 4.2625 for date_id 3365 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 1.657 for date_id 3365 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.18747 for date_id 3365 and factor_id 7
# Found date_id 3366 for date 2017-05-29
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.51407 for date_id 3366 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.13878 for date_id 3366 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 1.0229 for date_id 3366 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.2266 for date_id 3366 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.39393 for date_id 3366 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.91407 for date_id 3366 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.29907 for date_id 3366 and factor_id 7
# Found date_id 3367 for date 2017-06-04
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.30971 for date_id 3367 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.16071 for date_id 3367 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.65517 for date_id 3367 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.302 for date_id 3367 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.063461 for date_id 3367 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.28217 for date_id 3367 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.30715 for date_id 3367 and factor_id 7
# Found date_id 3368 for date 2017-06-10
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.3988 for date_id 3368 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.69029 for date_id 3368 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.67533 for date_id 3368 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.9884 for date_id 3368 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.14194 for date_id 3368 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.24589 for date_id 3368 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.069597 for date_id 3368 and factor_id 7
# Found date_id 3369 for date 2017-06-16
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.73647 for date_id 3369 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.6281 for date_id 3369 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 1.0317 for date_id 3369 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.0289 for date_id 3369 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.59591 for date_id 3369 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.43298 for date_id 3369 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.024073 for date_id 3369 and factor_id 7
# Found date_id 3370 for date 2017-07-21
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value -0.043491 for date_id 3370 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.20649 for date_id 3370 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.27289 for date_id 3370 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.3326 for date_id 3370 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.037618 for date_id 3370 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.17174 for date_id 3370 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.18764 for date_id 3370 and factor_id 7
# Found date_id 3371 for date 2017-07-27
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.83767 for date_id 3371 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.44549 for date_id 3371 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.87144 for date_id 3371 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.1579 for date_id 3371 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.65275 for date_id 3371 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.16782 for date_id 3371 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.16763 for date_id 3371 and factor_id 7
# Found date_id 3372 for date 2017-08-02
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.14461 for date_id 3372 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.16368 for date_id 3372 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.23642 for date_id 3372 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.11559 for date_id 3372 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.25905 for date_id 3372 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.10357 for date_id 3372 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.40647 for date_id 3372 and factor_id 7
# Found date_id 3373 for date 2017-08-08
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.81229 for date_id 3373 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.97059 for date_id 3373 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.59806 for date_id 3373 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.76369 for date_id 3373 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 1.1238 for date_id 3373 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 1.1759 for date_id 3373 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.17947 for date_id 3373 and factor_id 7
# Found date_id 3374 for date 2017-08-14
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.43194 for date_id 3374 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 1.1216 for date_id 3374 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.77412 for date_id 3374 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.90593 for date_id 3374 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.55458 for date_id 3374 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.18669 for date_id 3374 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.048533 for date_id 3374 and factor_id 7
# Found date_id 3375 for date 2017-08-20
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.13167 for date_id 3375 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.47145 for date_id 3375 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.38029 for date_id 3375 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.41664 for date_id 3375 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.009642 for date_id 3375 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.70989 for date_id 3375 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.047129 for date_id 3375 and factor_id 7
# Found date_id 3376 for date 2017-08-26
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.1161 for date_id 3376 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.55436 for date_id 3376 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.20402 for date_id 3376 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.36575 for date_id 3376 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.33235 for date_id 3376 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.52908 for date_id 3376 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.18482 for date_id 3376 and factor_id 7
# Found date_id 3377 for date 2017-09-01
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value -0.0090979 for date_id 3377 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value -0.017181 for date_id 3377 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value -0.013791 for date_id 3377 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.24738 for date_id 3377 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.037485 for date_id 3377 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.2 for date_id 3377 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.025611 for date_id 3377 and factor_id 7
# Found date_id 3378 for date 2017-09-07
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.0036288 for date_id 3378 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value -0.0093519 for date_id 3378 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.030049 for date_id 3378 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.13656 for date_id 3378 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value -0.012592 for date_id 3378 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.2 for date_id 3378 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.026181 for date_id 3378 and factor_id 7
# Found date_id 3379 for date 2017-09-13
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.34833 for date_id 3379 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.27661 for date_id 3379 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.31719 for date_id 3379 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.79929 for date_id 3379 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.36192 for date_id 3379 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.2 for date_id 3379 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.20131 for date_id 3379 and factor_id 7
# Found date_id 3380 for date 2017-09-19
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.11553 for date_id 3380 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.072704 for date_id 3380 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.4507 for date_id 3380 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.43755 for date_id 3380 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.141 for date_id 3380 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.058353 for date_id 3380 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.18917 for date_id 3380 and factor_id 7
# Found date_id 3381 for date 2017-09-25
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.39329 for date_id 3381 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.049637 for date_id 3381 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.42288 for date_id 3381 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.7301 for date_id 3381 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.64377 for date_id 3381 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.14721 for date_id 3381 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.6355 for date_id 3381 and factor_id 7
# Found date_id 3382 for date 2017-10-01
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value -0.030737 for date_id 3382 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.12608 for date_id 3382 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.15035 for date_id 3382 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.5328 for date_id 3382 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.009001 for date_id 3382 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.005759 for date_id 3382 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.25217 for date_id 3382 and factor_id 7
# Found date_id 3383 for date 2017-10-07
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.24048 for date_id 3383 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.40224 for date_id 3383 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.14953 for date_id 3383 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.80815 for date_id 3383 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.25506 for date_id 3383 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.017955 for date_id 3383 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.84444 for date_id 3383 and factor_id 7
# Found date_id 3384 for date 2017-10-13
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.4578 for date_id 3384 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.23106 for date_id 3384 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.56411 for date_id 3384 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.67819 for date_id 3384 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.38745 for date_id 3384 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.2 for date_id 3384 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.4837 for date_id 3384 and factor_id 7
# Found date_id 3385 for date 2017-10-19
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.54497 for date_id 3385 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.047589 for date_id 3385 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.39426 for date_id 3385 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.54827 for date_id 3385 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.22844 for date_id 3385 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.2 for date_id 3385 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.25554 for date_id 3385 and factor_id 7
# Found date_id 3386 for date 2017-10-25
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.23385 for date_id 3386 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.13842 for date_id 3386 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.60171 for date_id 3386 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.69965 for date_id 3386 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.51594 for date_id 3386 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.070259 for date_id 3386 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.45598 for date_id 3386 and factor_id 7
# Found date_id 3387 for date 2017-10-31
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.17517 for date_id 3387 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.23927 for date_id 3387 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.092402 for date_id 3387 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.66995 for date_id 3387 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.3191 for date_id 3387 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.2 for date_id 3387 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.2883 for date_id 3387 and factor_id 7
# Found date_id 3388 for date 2017-11-06
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.38471 for date_id 3388 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.15156 for date_id 3388 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.37146 for date_id 3388 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.0439 for date_id 3388 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.55339 for date_id 3388 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.017086 for date_id 3388 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.50075 for date_id 3388 and factor_id 7
# Found date_id 3389 for date 2017-11-12
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.52993 for date_id 3389 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.22604 for date_id 3389 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.28753 for date_id 3389 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.59414 for date_id 3389 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.18655 for date_id 3389 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 1.4597 for date_id 3389 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.24156 for date_id 3389 and factor_id 7
# Found date_id 3390 for date 2017-11-18
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 1.106 for date_id 3390 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.026602 for date_id 3390 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.13873 for date_id 3390 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.94587 for date_id 3390 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.27622 for date_id 3390 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.2 for date_id 3390 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.48728 for date_id 3390 and factor_id 7
# Found date_id 3391 for date 2017-11-24
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 1.1706 for date_id 3391 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value -0.0066282 for date_id 3391 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.42003 for date_id 3391 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.3422 for date_id 3391 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.40141 for date_id 3391 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.62363 for date_id 3391 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.2202 for date_id 3391 and factor_id 7
# Found date_id 3392 for date 2017-11-30
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.73324 for date_id 3392 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value -0.018331 for date_id 3392 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.26257 for date_id 3392 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.1947 for date_id 3392 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.43411 for date_id 3392 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.6485 for date_id 3392 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.7983 for date_id 3392 and factor_id 7
# Found date_id 3393 for date 2017-12-06
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.85574 for date_id 3393 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.13176 for date_id 3393 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.11258 for date_id 3393 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.94737 for date_id 3393 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.72744 for date_id 3393 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.22261 for date_id 3393 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.7507 for date_id 3393 and factor_id 7
# Found date_id 3394 for date 2017-12-12
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.49813 for date_id 3394 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.11493 for date_id 3394 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.22864 for date_id 3394 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.63149 for date_id 3394 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.24097 for date_id 3394 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.26751 for date_id 3394 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.0056 for date_id 3394 and factor_id 7
# Found date_id 3395 for date 2017-12-18
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.59637 for date_id 3395 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.25054 for date_id 3395 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.7431 for date_id 3395 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.3372 for date_id 3395 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 1.8153 for date_id 3395 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.92789 for date_id 3395 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.4155 for date_id 3395 and factor_id 7
# Found date_id 3396 for date 2017-12-24
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.027193 for date_id 3396 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.46668 for date_id 3396 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value -0.047805 for date_id 3396 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.68265 for date_id 3396 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value -0.021999 for date_id 3396 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.012535 for date_id 3396 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.1887 for date_id 3396 and factor_id 7
# Found date_id 3397 for date 2017-12-30
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.21825 for date_id 3397 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.05763 for date_id 3397 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.16328 for date_id 3397 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.63702 for date_id 3397 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.11556 for date_id 3397 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.26157 for date_id 3397 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.81257 for date_id 3397 and factor_id 7
# Found date_id 3398 for date 2018-01-05
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value -0.10162 for date_id 3398 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.28542 for date_id 3398 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.12015 for date_id 3398 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.39922 for date_id 3398 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.11136 for date_id 3398 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.2 for date_id 3398 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.3871 for date_id 3398 and factor_id 7
# Found date_id 3399 for date 2018-01-11
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.3585 for date_id 3399 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.053897 for date_id 3399 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.44035 for date_id 3399 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 1.0624 for date_id 3399 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.41348 for date_id 3399 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.78535 for date_id 3399 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.87571 for date_id 3399 and factor_id 7
# Found date_id 3400 for date 2018-01-17
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.045265 for date_id 3400 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 1.1529 for date_id 3400 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value -0.13717 for date_id 3400 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.58824 for date_id 3400 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.21425 for date_id 3400 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.26584 for date_id 3400 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.9064 for date_id 3400 and factor_id 7
# Found date_id 3401 for date 2018-01-23
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.29304 for date_id 3401 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.023773 for date_id 3401 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# ...
# Found date_id 3658 for date 2022-09-10
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.98371 for date_id 3658 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value -0.012509 for date_id 3658 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.164 for date_id 3658 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.29237 for date_id 3658 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.76777 for date_id 3658 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.41162 for date_id 3658 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.65336 for date_id 3658 and factor_id 7
# Found date_id 3659 for date 2022-09-16
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 1.4248 for date_id 3659 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.64798 for date_id 3659 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.66909 for date_id 3659 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.26644 for date_id 3659 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 2.2062 for date_id 3659 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.8923 for date_id 3659 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value -0.2 for date_id 3659 and factor_id 7
# Found date_id 3660 for date 2022-09-22
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.0031951 for date_id 3660 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value -0.0082413 for date_id 3660 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value -0.017964 for date_id 3660 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.10646 for date_id 3660 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.019069 for date_id 3660 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.035916 for date_id 3660 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.014497 for date_id 3660 and factor_id 7
# Found date_id 3661 for date 2022-09-28
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.081863 for date_id 3661 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.60655 for date_id 3661 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.33943 for date_id 3661 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.22469 for date_id 3661 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.96532 for date_id 3661 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.029932 for date_id 3661 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.79273 for date_id 3661 and factor_id 7
# Found date_id 3662 for date 2022-10-04
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.18183 for date_id 3662 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.6406 for date_id 3662 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.22501 for date_id 3662 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.063736 for date_id 3662 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.51163 for date_id 3662 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.6891 for date_id 3662 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.88644 for date_id 3662 and factor_id 7
# Found date_id 3663 for date 2022-10-10
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.14027 for date_id 3663 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.64028 for date_id 3663 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.23663 for date_id 3663 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.13048 for date_id 3663 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.40585 for date_id 3663 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.45112 for date_id 3663 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.55394 for date_id 3663 and factor_id 7
# Found date_id 3664 for date 2022-10-16
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.8915 for date_id 3664 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.45764 for date_id 3664 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.2671 for date_id 3664 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.2937 for date_id 3664 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 1.1462 for date_id 3664 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.20403 for date_id 3664 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.15912 for date_id 3664 and factor_id 7
# Found date_id 3665 for date 2022-10-22
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.012668 for date_id 3665 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value -0.010827 for date_id 3665 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value -0.0074524 for date_id 3665 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.15508 for date_id 3665 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.0024896 for date_id 3665 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value -0.17909 for date_id 3665 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.026078 for date_id 3665 and factor_id 7
# Found date_id 3666 for date 2022-10-28
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.41709 for date_id 3666 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 1.1032 for date_id 3666 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.093031 for date_id 3666 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.29248 for date_id 3666 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.74293 for date_id 3666 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.34827 for date_id 3666 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.3411 for date_id 3666 and factor_id 7
# Found date_id 3667 for date 2022-11-03
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.69779 for date_id 3667 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.3721 for date_id 3667 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.27608 for date_id 3667 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.49922 for date_id 3667 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.48127 for date_id 3667 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.37439 for date_id 3667 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.5312 for date_id 3667 and factor_id 7
# Found date_id 3668 for date 2022-11-09
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.45943 for date_id 3668 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.34698 for date_id 3668 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.34896 for date_id 3668 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.22203 for date_id 3668 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.55613 for date_id 3668 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.47905 for date_id 3668 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.68061 for date_id 3668 and factor_id 7
# Found date_id 3669 for date 2022-11-15
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.53868 for date_id 3669 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 1.3389 for date_id 3669 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.48518 for date_id 3669 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.14981 for date_id 3669 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 1.1831 for date_id 3669 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 1.3459 for date_id 3669 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.60661 for date_id 3669 and factor_id 7
# Found date_id 3670 for date 2022-11-21
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value -0.018082 for date_id 3670 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.018596 for date_id 3670 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value -0.0020506 for date_id 3670 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.12995 for date_id 3670 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.038436 for date_id 3670 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.086748 for date_id 3670 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.10026 for date_id 3670 and factor_id 7
# Found date_id 3671 for date 2022-11-27
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value -0.025198 for date_id 3671 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.49514 for date_id 3671 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.20844 for date_id 3671 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.22976 for date_id 3671 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.24779 for date_id 3671 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.87761 for date_id 3671 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.47528 for date_id 3671 and factor_id 7
# Found date_id 3672 for date 2022-12-03
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.37984 for date_id 3672 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 1.1617 for date_id 3672 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.25032 for date_id 3672 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.44057 for date_id 3672 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.45468 for date_id 3672 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.34866 for date_id 3672 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.36294 for date_id 3672 and factor_id 7
# Found date_id 3673 for date 2022-12-09
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value -0.16833 for date_id 3673 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.55372 for date_id 3673 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.20551 for date_id 3673 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.10837 for date_id 3673 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.20553 for date_id 3673 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.33374 for date_id 3673 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.5296 for date_id 3673 and factor_id 7
# Found date_id 3674 for date 2022-12-15
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.20323 for date_id 3674 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.15687 for date_id 3674 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.12945 for date_id 3674 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.13114 for date_id 3674 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.13171 for date_id 3674 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.3641 for date_id 3674 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.20081 for date_id 3674 and factor_id 7
# Found date_id 3675 for date 2022-12-21
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.54835 for date_id 3675 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.3482 for date_id 3675 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value 0.22288 for date_id 3675 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.3257 for date_id 3675 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.60809 for date_id 3675 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.45162 for date_id 3675 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 0.88107 for date_id 3675 and factor_id 7
# Found date_id 3676 for date 2022-12-27
# Found factor_id 1 for factor Soil/Road dust
# Inserted contribution value 0.40598 for date_id 3676 and factor_id 1
# Found factor_id 2 for factor Sea salt
# Inserted contribution value 0.64801 for date_id 3676 and factor_id 2
# Found factor_id 3 for factor Diesel vehicles
# Inserted contribution value -0.10268 for date_id 3676 and factor_id 3
# Found factor_id 4 for factor Biomass burning
# Inserted contribution value 0.32348 for date_id 3676 and factor_id 4
# Found factor_id 5 for factor Construction
# Inserted contribution value 0.22307 for date_id 3676 and factor_id 5
# Found factor_id 6 for factor Petrol vehicles
# Inserted contribution value 0.70669 for date_id 3676 and factor_id 6
# Found factor_id 7 for factor Sulphate/Marine diesel
# Inserted contribution value 1.5581 for date_id 3676 and factor_id 7
# Contributions have been inserted into the Contributions table.
# Database connection closed.

# %% [markdown]
# # Testing

# %%
# 验证factor table
def verify_factors_in_database(db_filename, df1):
    # 连接到SQLite数据库
    conn = sqlite3.connect(db_filename)
    cursor = conn.cursor()
    print("Connected to the database.")

    # 查询Factors表中的所有数据
    try:
        cursor.execute("SELECT * FROM Factors")
        factors_from_db = cursor.fetchall()
        print("Data fetched from the Factors table.")
    except Exception as e:
        print(f"An error occurred while fetching data: {e}")
        return

    # 将查询结果转换为DataFrame以便比较
    factors_df = pd.DataFrame(factors_from_db, columns=['factor_id', 'factor_name'])
    print("Converted fetched data to DataFrame.")

    # 获取df1的第三列开始的列名
    expected_factors = df1.columns[2:].tolist()
    print("Expected factors:", expected_factors)

    # 检查数据库中的因子是否与df1中的因子相匹配
    if set(factors_df['factor_name']) == set(expected_factors):
        print("Verification successful: All factors from df1 are present in the Factors table.")
    else:
        print("Verification failed: There are discrepancies between df1 and the Factors table.")

    # 关闭连接
    conn.close()
    print("Database connection closed.")

# 使用验证函数
verify_factors_in_database(db_filename, df1)
# Out:
# Connected to the database.
# Data fetched from the Factors table.
# Converted fetched data to DataFrame.
# Expected factors: ['Soil/Road dust', 'Sea salt', 'Diesel vehicles', 'Biomass burning', 'Construction', 'Petrol vehicles', 'Sulphate/Marine diesel']
# Verification successful: All factors from df1 are present in the Factors table.
# Database connection closed.

# %%
import sqlite3
from datetime import datetime

def query_contribution(db_filename, date_str, factor_name):
    # 连接到SQLite数据库
    conn = sqlite3.connect(db_filename)
    cursor = conn.cursor()

    # 将日期字符串转换为 YYYY-MM-DD 格式
    try:
        # 尝试解析日期字符串，假设格式为 'M/D/YYYY'
        parsed_date = datetime.strptime(date_str, '%m/%d/%Y')
        # 格式化为 'YYYY-MM-DD'
        date_str_formatted = parsed_date.strftime('%Y-%m-%d')
    except ValueError:
        print("Date string is not in the expected format 'M/D/YYYY'")
        return

    # 准备查询date_id的SQL语句
    get_date_id = "SELECT date_id FROM Dates WHERE date = ?"

    # 准备查询factor_id的SQL语句
    get_factor_id = "SELECT factor_id FROM Factors WHERE factor_name = ?"

    # 准备查询贡献值的SQL语句
    get_contribution = """
    SELECT contribution_value FROM Contributions
    WHERE date_id = (SELECT date_id FROM Dates WHERE date = ?)
    AND factor_id = (SELECT factor_id FROM Factors WHERE factor_name = ?)
    """

    try:
        # 获取date_id
        cursor.execute(get_date_id, (date_str_formatted,))
        date_id_result = cursor.fetchone()
        if date_id_result:
            date_id = date_id_result[0]
            print(f"Found date_id {date_id} for date {date_str_formatted}")
        else:
            print(f"No matching date_id found for date {date_str_formatted}")
            return

        # 获取factor_id
        cursor.execute(get_factor_id, (factor_name,))
        factor_id_result = cursor.fetchone()
        if factor_id_result:
            factor_id = factor_id_result[0]
            print(f"Found factor_id {factor_id} for factor {factor_name}")
            # 查询贡献值
            cursor.execute(get_contribution, (date_str_formatted, factor_name,))
            contribution_result = cursor.fetchone()
            if contribution_result:
                print(f"Contribution value for {date_str_formatted} and {factor_name} is {contribution_result[0]}")
            else:
                print(f"No contribution value found for {date_str_formatted} and {factor_name}")
        else:
            print(f"No matching factor_id found for factor {factor_name}")
    except Exception as e:
        print(f"An error occurred: {e}")

    finally:
        # 关闭连接
        conn.close()

# 使用函数查询数据
db_filename = 'trend_analysis_contributions.db'
query_date = '1/30/2006'
query_factor = 'Soil/Road dust'
query_contribution(db_filename, query_date, query_factor)
# Out:
# Found date_id 22 for date 2006-01-30
# Found factor_id 1 for factor Soil/Road dust
# Contribution value for 2006-01-30 and Soil/Road dust is 0.24937
